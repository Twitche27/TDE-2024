# %%
import pandas as pd

# %% [markdown]
# leitura do dataset e alteração do index para ser a Localidade, transpondo-o

# %%
colunas = ['Localidade', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
linhas = [0, 5, 16, 20, 21, 26]
df = pd.read_csv('Índice de Desenvolvimento Humano.csv',usecols=colunas, skiprows=lambda x: x not in linhas)
df = df.set_index('Localidade').T
df
# Out:
# Localidade   Pará  Bahia  São Paulo  Paraná  Goiás
# 2014        0.684  0.694      0.825   0.788  0.757
# 2015        0.689  0.701      0.823   0.786  0.755
# 2016        0.687  0.705      0.835   0.797  0.764
# 2017        0.694  0.710      0.831   0.797  0.765
# 2018        0.707  0.710      0.837   0.805  0.771
# 2019        0.704  0.718      0.845   0.807  0.774
# 2020        0.719  0.724      0.823   0.787  0.758
# 2021        0.690  0.691      0.806   0.769  0.737

# %% [markdown]
# Geração do gráfico

# %%
df.plot(title='IDH nos Estados mais Populosos do Brasil ao Longo do Tempo')
# Out:
# <Axes: title={'center': 'IDH nos Estados mais Populosos do Brasil ao Longo do Tempo'}>
